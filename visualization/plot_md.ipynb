# %%
import os
import numpy as np
import imageio

# %%
raw_path = '../md17'

# %%
molecule_files = dict(
    Aspirin="aspirin_dft.npz",
    Benzene="benzene_dft.npz",
    Ethanol="ethanol_dft.npz",
    Malonaldehyde="malonaldehyde_dft.npz",
    Naphthalene="naphthalene_dft.npz",
    Salicylic="salicylic_dft.npz",
    Toluene="toluene_dft.npz",
    Uracil="uracil_dft.npz",
)

# %%
def read_mol(mol_name):
    npz_file = np.load(os.path.join(raw_path, molecule_files[mol_name]))
    z = npz_file['z']
    x_all = npz_file['R']
    x = x_all[:, z > 1]
    return z, x_all, x

# %%
tar_mol = 'Malonaldehyde'
z, x_all, x = read_mol(tar_mol)
print(z)
# Out:
# [6 6 6 8 8 1 1 1 1]

# %%
dic = {1:'H', 6: 'C', 8:'O', 7:'N'}

# %%
from xyz2mol import *

# %%
now_index = 128047
past_index = [now_index - i*10  for i in range(10, 0, -1)]
past_index
# Out:
# [127947,
#  127957,
#  127967,
#  127977,
#  127987,
#  127997,
#  128007,
#  128017,
#  128027,
#  128037]

# %%
def get_mol(ind):
    print(ind)
    x_mol = x_all[ind]
    mols = xyz2mol(z.tolist(), x_mol.tolist(),
                charge=0,
                use_graph=True,
                allow_charged_fragments=True,
                embed_chiral=True,
                use_huckel=False)
    return mols[0]

# %%
example_mol = get_mol(now_index)
example_mol
# Out:
# 128047

# %%
from rdkit.Chem import PyMol
v = PyMol.MolViewer()
from PIL import Image, ImageDraw, ImageFont

def cuthead(img, size=10):
    im = np.array(img)
    cutspace = im[:size,:,:]
    cvs = np.ones_like(cutspace) * 255
    im[:size,:,:] = cvs   
    img2 = Image.fromarray(im).convert('RGB')
    return img2

def add_caption(img, molecule, method, step, mae = None, fontsize=20):
    ime = ImageDraw.Draw(img)
    # ft = ImageFont.truetype("times.ttf",size=fontsize)
    ft = ImageFont.load_default()
    ime.text((10,10),f"{molecule}, {method}",(0,0,0),font=ft)
    if mae is not None:
        ime.text((10,15+fontsize),f"Step={step}, MAE={mae:.4f}",(0,0,0),font=ft)
    else:
        ime.text((10,15+fontsize),f"Step={step}",(0,0,0),font=ft)


def show(ind):
    example_mol = get_mol(ind)
    # Visualize the example
    # v = PyMol.MolViewer()
    v.ShowMol(example_mol)
    v.server.do("color yellow, elem c")
    v.server.do("color orange, elem h")
    v.server.do("color blue, elem n")
    v.server.do("color red, elem o")
    img = v.GetPNG(h=300)
    # You may adjust the view in PyMol for better visualization
    img = cuthead(img)
    # add_caption(img, tar_mol, 'Example', 0, mae = 0.0, fontsize = 15)
    return img

# %%
img = show(past_index[10])
# Out:
# 128047

# %%
img.save(f'vis/{tar_mol}_gt.png')

# %%
def set_rdmol_positions(rdkit_mol, pos):
    """
    Args:
        rdkit_mol:  An `rdkit.Chem.rdchem.Mol` object.
        pos: (N_atoms, 3)
    """
    mol = copy.deepcopy(rdkit_mol)
    set_rdmol_positions_(mol, pos)
    return mol


def set_rdmol_positions_(mol, pos):
    """
    Args:
        rdkit_mol:  An `rdkit.Chem.rdchem.Mol` object.
        pos: (N_atoms, 3)
    """
    for i in range(pos.shape[0]):
        mol.GetConformer(0).SetAtomPosition(i, pos[i].tolist())
    return mol

# %%
loc_pred = np.array([[-1.1885,  0.3116, -0.6747],
        [-0.0237,  0.8144, -1.1451],        [ 1.2061,  0.4384, -0.5264],        [ 1.2043, -0.2609,  0.6985],        [-0.0281, -0.8106,  1.1351],
        [-1.2149, -0.4542,  0.5240]])

# %%
print(loc_pred.shape)
# Out:
# (8, 3)

# %%
# x = np.array(x_all[now_index])

x = np.array([[-1.1841,  0.3039, -0.6663],        [-0.0100,  0.7965, -1.1339],        [ 1.2122,  0.4357, -0.5211],        [ 1.2202, -0.2841,  0.7040],        [-0.0149, -0.8246,  1.1363],        [-1.2044, -0.4706,  0.5270],        [-2.1085,  0.6681, -1.1761],        [ 0.0214,  1.3515, -2.0826],
        [ 2.1358,  0.8502, -0.8732],        [ 2.1501, -0.5980,  1.1671],        [-0.0215, -1.5188,  1.9750],        [-2.1958, -0.7096,  0.9437]])
x[np.array(z) > 1] = loc_pred

# %%
try:
    mols = xyz2mol(z, x,
                    charge=0,
                    use_graph=True,
                    allow_charged_fragments=True,
                    embed_chiral=True,
                    use_huckel=False)
except Exception as e:
    print(e)

# print(mols)
mol = mols[0]
v.ShowMol(mol)
v.server.do("color yellow, elem c")
v.server.do("color orange, elem h")
v.server.do("color blue, elem n")
v.server.do("color red, elem o")
img = v.GetPNG(h=300)
# You may adjust the view in PyMol for better visualization
img = cuthead(img)

# %%
img.save(f'vis/{tar_mol}_egnn.png')

# %%
from rdkit.Chem import PyMol

# %% [markdown]
# Run 'pymol -R' in Bash before the following block to start PyMol first.

# %%
v = PyMol.MolViewer()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-33-2f70a9c7a100> in <module>
# ----> 1 v = PyMol.MolViewer()
#
# ~/anaconda3/envs/protein/lib/python3.6/site-packages/rdkit/Chem/PyMol.py in __init__(self, host, port, force, **kwargs)
#      35       _server = None
#      36       serv = Server('http://%s:%d' % (host, port))
# ---> 37       serv.ping()
#      38       _server = serv
#      39       self.server = serv
#
# ~/anaconda3/envs/protein/lib/python3.6/xmlrpc/client.py in __call__(self, *args)
#    1110         return _Method(self.__send, "%s.%s" % (self.__name, name))
#    1111     def __call__(self, *args):
# -> 1112         return self.__send(self.__name, args)
#    1113
#    1114 ##
#
# ~/anaconda3/envs/protein/lib/python3.6/xmlrpc/client.py in __request(self, methodname, params)
#    1450             self.__handler,
#    1451             request,
# -> 1452             verbose=self.__verbose
#    1453             )
#    1454
#
# ~/anaconda3/envs/protein/lib/python3.6/xmlrpc/client.py in request(self, host, handler, request_body, verbose)
#    1152         for i in (0, 1):
#    1153             try:
# -> 1154                 return self.single_request(host, handler, request_body, verbose)
#    1155             except http.client.RemoteDisconnected:
#    1156                 if i:
#
# ~/anaconda3/envs/protein/lib/python3.6/xmlrpc/client.py in single_request(self, host, handler, request_body, verbose)
#    1164         # issue XML-RPC request
#    1165         try:
# -> 1166             http_conn = self.send_request(host, handler, request_body, verbose)
#    1167             resp = http_conn.getresponse()
#    1168             if resp.status == 200:
#
# ~/anaconda3/envs/protein/lib/python3.6/xmlrpc/client.py in send_request(self, host, handler, request_body, debug)
#    1277         headers.append(("User-Agent", self.user_agent))
#    1278         self.send_headers(connection, headers)
# -> 1279         self.send_content(connection, request_body)
#    1280         return connection
#    1281
#
# ~/anaconda3/envs/protein/lib/python3.6/xmlrpc/client.py in send_content(self, connection, request_body)
#    1307
#    1308         connection.putheader("Content-Length", str(len(request_body)))
# -> 1309         connection.endheaders(request_body)
#    1310
#    1311     ##
#
# ~/anaconda3/envs/protein/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1280         else:
#    1281             raise CannotSendHeader()
# -> 1282         self._send_output(message_body, encode_chunked=encode_chunked)
#    1283
#    1284     def request(self, method, url, body=None, headers={}, *,
#
# ~/anaconda3/envs/protein/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1040         msg = b"\r\n".join(self._buffer)
#    1041         del self._buffer[:]
# -> 1042         self.send(msg)
#    1043
#    1044         if message_body is not None:
#
# ~/anaconda3/envs/protein/lib/python3.6/http/client.py in send(self, data)
#     978         if self.sock is None:
#     979             if self.auto_open:
# --> 980                 self.connect()
#     981             else:
#     982                 raise NotConnected()
#
# ~/anaconda3/envs/protein/lib/python3.6/http/client.py in connect(self)
#     950         """Connect to the host and port specified in __init__."""
#     951         self.sock = self._create_connection(
# --> 952             (self.host,self.port), self.timeout, self.source_address)
#     953         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     954
#
# ~/anaconda3/envs/protein/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     722
#     723     if err is not None:
# --> 724         raise err
#     725     else:
#     726         raise error("getaddrinfo returns an empty list")
#
# ~/anaconda3/envs/protein/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     711             if source_address:
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#     715             err = None
#
# ConnectionRefusedError: [Errno 111] Connection refused

# %% [markdown]
# ## Settings in PyMol
#
# Display -> Background -> White
#
# Display -> Color Space -> CMYK
#
# Setting -> Lines & Sticks -> Ball and Stick
#
# Setting -> Lines & Sticks -> Ball and Stick Ratio -> 1.5
#
# (PyMol>) set stick_radius=0.15

# %%
from PIL import Image, ImageDraw, ImageFont

# %%
def cuthead(img, size=10):
    im = np.array(img)
    cutspace = im[:size,:,:]
    cvs = np.ones_like(cutspace) * 255
    im[:size,:,:] = cvs   
    img2 = Image.fromarray(im).convert('RGB')
    return img2

# %%
def add_caption(img, molecule, method, step, mae = None, fontsize=20):
    ime = ImageDraw.Draw(img)
    ft = ImageFont.truetype("times.ttf",size=fontsize)
    ime.text((10,10),f"{molecule}, {method}",(0,0,0),font=ft)
    if mae is not None:
        ime.text((10,15+fontsize),f"Step={step}, MAE={mae:.4f}",(0,0,0),font=ft)
    else:
        ime.text((10,15+fontsize),f"Step={step}",(0,0,0),font=ft)

# %%
# Visualize the example
v.ShowMol(example_mol)
v.server.do("color yellow, elem c")
v.server.do("color orange, elem h")
v.server.do("color blue, elem n")
v.server.do("color red, elem o")
img = v.GetPNG(h=300)
# You may adjust the view in PyMol for better visualization
img = cuthead(img)
add_caption(img, tar_mol, 'Example', 0, mae = 0.0, fontsize = 15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-2f203c43e52c> in <module>
#       1 # Visualize the example
# ----> 2 v.ShowMol(example_mol)
#       3 v.server.do("color yellow, elem c")
#       4 v.server.do("color orange, elem h")
#       5 v.server.do("color blue, elem n")
#
# NameError: name 'v' is not defined

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=358x300 at 0x7FF0A823BE10>

# %%
os.makedirs('vis',exist_ok=True)

# %%
from tqdm import tqdm

# %%
tar_mol = 'Uracil'
z, x_all, x = read_mol(tar_mol)
x.shape
# Out:
# (133770, 8, 3)

# %%
temp_x = x[127947:max(327947, len(x))]
temp_x.shape
# Out:
# (5823, 8, 3)

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams.update({'font.size': 15})
plt.figure(figsize=(15, 6))

# %%
data = temp_x[:, 0, 2]
data = data / np.max(np.abs(data))
plt.xlabel('t')
plt.ylabel('coordinates')
plt.title(tar_mol.upper())
plt.plot(data)
plt.savefig(f'vis/{tar_mol}_T.pdf')
plt.show()
